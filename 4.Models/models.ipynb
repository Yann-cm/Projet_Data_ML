# %%
import pandas as pd

df = pd.read_csv("../6.Data/Yann_Process_train.csv")
df_test = pd.read_csv("../6.Data/Yann_Process_test.csv")
pd.set_option('display.max_columns',200)
df.head()
# Out:
#        customer_id       age  tenure_months  annual_income_eur  credit_score  \
# 0  CUST_6O9Q8D4I36 -0.365440       3.774957           0.097221     -2.196938
# 1  CUST_FGUGTW230C  0.858317      -0.925176          -0.824662      0.573317
# 2  CUST_8ZI3LCBZ0W -0.977319      -1.042680          -0.804282      0.869508
# 3  CUST_5MP3AR41CJ  0.596083       1.836152           0.088233      0.573317
# 4  CUST_GNPL83JB0J -0.103206       1.659897          -0.232290     -1.325788
#
#    num_transactions_30d  avg_amount_30d_eur  max_amount_30d_eur  \
# 0             -0.083441            0.003497           -0.892335
# 1             -0.054686            1.311115            1.170780
# 2              0.060335            0.327655            0.840696
# 3             -0.169706           -0.338543           -0.371178
# 4             -0.284726            1.000495            1.855613
#
#    days_since_last_login  support_tickets_90d  chargebacks_12m  \
# ...
