# %% [markdown]
# # Preprocessing – Version Simple
# Objectif :
# - Garder uniquement les variables numériques
# - Imputation médiane
# - StandardScaler
# - Export train & test preprocessés

# %%
import pandas as pd
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler

# %%
train = pd.read_csv('../data/train.csv')
test = pd.read_csv('../data/test.csv')

target = 'target_is_fraud'
id_col = 'customer_id'

# %%
num_cols = train.select_dtypes(include='number').columns.tolist()
num_cols.remove(target)

X_train = train[num_cols]
y_train = train[target]
X_test = test[num_cols]

# %%
pipeline = Pipeline([
    ('imputer', SimpleImputer(strategy='median')),
    ('scaler', StandardScaler())
])

# %%
pipeline
# Out:
# Pipeline(steps=[('imputer', SimpleImputer(strategy='median')),
#                 ('scaler', StandardScaler())])

# %%
X_train_processed = pipeline.fit_transform(X_train)
X_test_processed = pipeline.transform(X_test)

# %%
X_test_processed
# Out:
#             age  tenure_months  annual_income_eur  credit_score  \
# 0      0.405151       1.974080          -0.446862     -0.531232
# 1     -1.381932      -0.725390           0.313767      0.494841
# 2      0.320052      -0.894107          -0.021937      1.623522
# 3      0.064754       0.118194          -0.266389     -1.659912
# 4      1.341242      -0.444195          -0.073802     -0.787750
# ...         ...            ...                ...           ...
# 39995  0.490250      -0.837868           0.165921     -0.821953
# 39996  0.830647      -0.331717          -0.016552      0.460639
# 39997  0.915746       0.568106           0.720593     -0.206309
# 39998 -0.616040      -0.612912          -1.059834      0.221222
# 39999 -1.722329       0.961779          -0.613095      0.871068
#
#        num_transactions_30d  avg_amount_30d_eur  max_amount_30d_eur  \
# 0                  0.031580            1.121707            1.945076
# 1                 -0.054686           -0.170351           -0.168194
# 2                 -0.169706           -0.411072           -0.224804
# 3                  0.175355           -0.561369            0.105619
# 4                 -0.054686            0.242595            0.981311
# ...                     ...                 ...                 ...
# 39995              0.031580           -0.445813           -0.321512
# 39996              0.060335           -0.983432           -0.902841
# 39997             -0.140951            2.944239            0.460350
# 39998             -0.112196            1.696284            1.391692
# 39999             -0.054686           -0.987620           -0.546552
#
#        days_since_last_login  support_tickets_90d  chargebacks_12m  ...  \
# 0                  -0.392225            -0.891739         -0.22369  ...
# 1                  -0.649837             0.225939         -0.22369  ...
# 2                  -0.417155             0.225939         -0.22369  ...
# 3                   1.352889            -0.891739         -0.22369  ...
# 4                   0.804425            -0.891739         -0.22369  ...
# ...                      ...                  ...              ...  ...
# 39995              -0.392225            -0.891739         -0.22369  ...
# 39996              -0.683077             0.225939         -0.22369  ...
# 39997              -0.699697             1.343616         -0.22369  ...
# 39998               0.156240            -0.891739         -0.22369  ...
# 39999               0.812735            -0.891739         -0.22369  ...
#
#        internal_signal_5  internal_signal_6  internal_signal_7  \
# 0              -1.330796          -0.672180           0.965216
# 1               0.386111           0.989568           1.560813
# 2              -1.025280          -1.155672          -0.333538
# 3               0.871787           0.474384           0.413345
# 4              -0.053347          -0.023893          -0.221923
# ...                  ...                ...                ...
# 39995           0.001689           2.305880          -0.555070
# 39996          -0.000446           1.452900          -0.084757
# 39997           0.156025          -0.742089           1.376084
# 39998           3.033142          -0.634302          -0.006707
# 39999          -0.036602          -0.076335           1.181561
#
#        internal_signal_8  terms_accepted_flag  partner_risk_indicator  \
# 0               0.136368                  0.0                0.001732
# 1               1.055360                  0.0                0.001732
# 2              -0.152801                  0.0                0.001732
# 3               0.233907                  0.0                0.001732
# 4              -0.888005                  0.0                0.001732
# ...                  ...                  ...                     ...
# 39995           1.381346                  0.0               -2.650908
# 39996          -0.983719                  0.0                0.001732
# 39997           1.146522                  0.0                0.001732
# 39998           1.533049                  0.0                0.001732
# 39999           0.298478                  0.0                0.001732
#
#        post_event_status_code  chargeback_resolution_time_days  \
# 0                   -0.295131                         0.397305
# 1                   -0.295131                         0.361217
# 2                   -0.295131                        -0.270321
# 3                    2.000995                        -1.136432
# 4                    4.297122                         1.263416
# ...                       ...                              ...
# 39995               -0.295131                         0.234910
# 39996               -0.295131                        -0.252277
# 39997               -0.295131                         1.786691
# 39998                4.297122                        -0.937948
# 39999               -0.295131                         0.289042
#
#        legacy_partner_score      customer_id
# 0                  0.000097  CUST_E5RX1BC9II
# 1                  0.000097  CUST_BHWIUKERGN
# 2                  0.000097  CUST_EXT9NA4CHU
# 3                  0.000097  CUST_9FSJE5R1NY
# 4                  0.000097  CUST_GDQXMODBED
# ...                     ...              ...
# 39995              0.000097  CUST_1OM9UCID91
# 39996              0.000097  CUST_VDEY72BIZP
# 39997              0.000097  CUST_UQEZ9KKIFG
# 39998              0.000097  CUST_IXX0BE9VQD
# 39999              0.000097  CUST_1TZOK0TGKK
#
# [40000 rows x 36 columns]

# %%
X_train_processed = pd.DataFrame(X_train_processed, columns=num_cols)
X_train_processed[target] = y_train.values
X_train_processed[id_col] = train[id_col].values

X_test_processed = pd.DataFrame(X_test_processed, columns=num_cols)
X_test_processed[id_col] = test[id_col].values

X_train_processed.to_csv('../data/train_preprocessed_simple.csv', index=False)
X_test_processed.to_csv('../data/test_preprocessed_simple.csv', index=False)

print('Export terminé.')
# Out:
# Export terminé.
