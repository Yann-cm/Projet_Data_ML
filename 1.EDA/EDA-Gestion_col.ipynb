# %%
import pandas as pd

# %% [markdown]
# | Colonne                             | Description                                            | Explication métier                                   | Intéressant à garder |
# | ----------------------------------- | ------------------------------------------------------ | ---------------------------------------------------- | -------------------- |
# | **target_is_fraud**                 | Indique si l’account est associé à un futur chargeback | Cible principale pour la classification              | Oui                  |
# | **customer_id**                     | Identifiant unique du client                           | Sert uniquement au suivi, pas de valeur prédictive   | Non                  |
# | **account_id**                      | Identifiant du compte                                  | Idem, suivi et soumission                            | Non                  |
# | **age**                             | Âge du client                                          | Peut influencer le comportement de paiement          | Oui                  |
# | **tenure_months**                   | Ancienneté du compte en mois                           | Les clients récents peuvent présenter plus de risque | Oui                  |
# | **annual_income_eur**               | Revenu annuel estimé en euros                          | Corrélé à capacité de paiement et risque             | Oui                  |
# | **credit_score**                    | Score de solvabilité                                   | Fortement lié au risque de défaut/fraude             | Oui                  |
# | **num_transactions_30d**            | Nombre de transactions sur 30 jours                    | Volume d’activité, indicateur comportemental         | Oui                  |
# | **avg_amount_30d_eur**              | Montant moyen des transactions sur 30 jours            | Détecter comportements atypiques ou gros montants    | Oui                  |
# | **max_amount_30d_eur**              | Montant max des transactions sur 30 jours              | Signale transactions inhabituelles                   | Oui                  |
# | **tx_amount_total_30d_eur**         | Montant total des transactions sur 30 jours            | Volume global, peut révéler fraude                   | Oui                  |
# | **max_to_avg_ratio**                | Ratio max/moyenne transactions                         | Très utile pour détecter anomalies                   | Oui                  |
# | **days_since_last_login**           | Jours depuis dernière connexion                        | Les comptes inactifs peuvent masquer fraude          | Oui                  |
# | **support_tickets_90d**             | Nb de tickets support sur 90 jours                     | Clients insatisfaits peuvent générer chargeback      | Oui                  |
# | **chargebacks_12m**                 | Nb de chargebacks sur 12 mois                          | Historique de fraude, très prédictif                 | Oui                  |
# | **failed_payments_6m**              | Nb de paiements échoués sur 6 mois                     | Signale problèmes ou comportements suspects          | Oui                  |
# | **device_trust_z**                  | Score standardisé confiance device                     | Permet de détecter appareils suspects                | Oui                  |
# | **ip_risk_z**                       | Score standardisé risque IP                            | Identifie connexions potentiellement frauduleuses    | Oui                  |
# | **is_vpn**                          | Connexion via VPN                                      | VPN peut masquer fraude                              | Oui                  |
# | **num_devices_30d**                 | Nb d’appareils distincts utilisés                      | Multiples appareils peuvent indiquer fraude          | Oui                  |
# | **is_new_device**                   | Nouveau device détecté récemment                       | Risque plus élevé sur nouveaux devices               | Oui                  |
# | **device_type**                     | Type de device (phone/desktop/tablet)                  | Peut moduler le risque selon usage                   | Oui                  |
# | **channel**                         | Canal d’interaction principal                          | Différences de risque entre app/web                  | Oui                  |
# | **signup_source**                   | Source d’acquisition                                   | Certaines sources plus risquées                      | Oui                  |
# | **plan_type**                       | Type de plan                                           | Peut influencer comportement ou limites              | Oui                  |
# | **payment_method**                  | Méthode de paiement principale                         | Certaines méthodes plus susceptibles de fraude       | Oui                  |
# | **country**                         | Pays du client                                         | Règles locales / risque régional                     | Oui                  |
# | **region**                          | Région administrative                                  | Plus fin que le pays, utile si données stables       | Oui                  |
# | **city**                            | Ville associée au compte                               | Trop spécifique, risque overfitting                  | Non                  |
# | **postal_code**                     | Code postal                                            | Trop spécifique, peu généralisable                   | Non                  |
# | **last_ticket_subject**             | Sujet dernier ticket support                           | Peut extraire mots clés (refund/fraud)               | Oui                  |
# | **customer_note**                   | Note interne client                                    | Même logique, utile pour features textuelles         | Oui                  |
# | **occupation**                      | Profession du client                                   | Influence solvabilité et comportements               | Oui                  |
# | **merchant_category**               | Catégorie des marchands                                | Permet de détecter comportements atypiques           | Oui                  |
# | **annual_income_log**               | Revenu log-transformé                                  | Utile pour normalisation, alternative à income       | Oui                  |
# | **income_dup_eur**                  | Alternative revenue                                    | Redondant avec annual_income_eur                     | Non                  |
# | **credit_score_scaled**             | Score crédit normalisé                                 | Redondant avec credit_score                          | Non                  |
# | **chargeback_resolution_time_days** | Délai résolution chargeback                            | Info post-fait, fuite de donnée                      | Non                  |
# | **post_event_status_code**          | Code status interne événements                         | Contient info future → fuite                         | Non                  |
# | **referrer_code**                   | Code attribution marketing                             | Peu prédictif, high cardinality                      | Non                  |
# | **secondary_email**                 | Email secondaire                                       | Peu prédictif                                        | Non                  |
# | **manual_review_result**            | Résultat revue interne                                 | Info future → fuite                                  | Non                  |
# | **legacy_partner_score**            | Score partenaire externe                               | Potentiellement utile si fiable                      | Oui                  |
# | **partner_risk_indicator**          | Indicateur tiers                                       | Utile si présent, sinon NA                           | Oui                  |
# | **terms_accepted_flag**             | Acceptation CGU                                        | Peu informatif pour fraude                           | Non                  |
# | **internal_signal_1 … 8**           | Signaux opérationnels internes                         | Très utile pour détection risque                     | Oui                  |
# | **signup_date**                     | Date création compte                                   | Transformable en ancienneté et saisonnalité          | Oui                  |
